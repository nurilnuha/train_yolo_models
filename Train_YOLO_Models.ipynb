# %% [markdown]
# <a href="https://colab.research.google.com/github/nurilnuha/train_yolo_models/blob/main/Train_YOLO_Models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Train YOLO Models in Google Colab
# **Author:** Evan Juras, [EJ Technology Consultants](https://ejtech.io)
#
# **Last updated:** January 3, 2025
#
# **GitHub:** [Train and Deploy YOLO Models](https://github.com/EdjeElectronics/Train-and-Deploy-YOLO-Models)
#
# # Introduction
#
# This notebook uses [Ultralytics](https://docs.ultralytics.com/) to train YOLO11, YOLOv8, or YOLOv5 object detection models with a custom dataset. At the end of this Colab, you'll have a custom YOLO model that you can run on your PC, phone, or edge device like the Raspberry Pi.
#
# <p align=center>
# <img src="https://s3.us-west-1.amazonaws.com/evanjuras.com/img/yolo-model-demo.gif" height="360"><br>
# <i>Custom YOLO candy detection model in action!</i>
# </p>
#
# I created a YouTube video that walks through this guide step by step. I recommend following along with the video while working through this notebook.
#
# <p align=center>
# <a href="https://youtu.be/r0RspiLG260" target="_blank"><img src="https://raw.githubusercontent.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/refs/heads/main/doc/Train_YOLO_Thumbnail2.png" height="240"><br>
# <i>Click here to go to the video!</i></a>
# </p>
#
# **Important note: This notebook will be continuously updated to make sure it works with newer versions of Ultralytics and YOLO. If you see any differences between the YouTube video and this notebook, always follow the notebook!**
#
# ### Working in Colab
# Colab provides a virtual machine in your browser complete with a Linux OS, filesystem, Python environment, and best of all, a free GPU. We'll install PyTorch and Ultralytics in this environment and use it to train our model. Simply click the Play button on sections of code in this notebook to execute them on the virtual machine.
#
# ### Navigation
# To navigate this notebook, use the table of contents in the left sidebar to jump from section to section.

# %% [markdown]
# **Verify NVIDIA GPU Availability**
#
# Make sure you're using a GPU-equipped machine by going to "Runtime" -> "Change runtime type" in the top menu bar, and then selecting one of the GPU options in the Hardware accelerator section. Click Play on the following code block to verify that the NVIDIA GPU is present and ready for training.

# %%
# !nvidia-smi
# Out:
# Sat Jun 27 00:06:31 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   41C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# #1.&nbsp;Gather and Label Training Images

# %% [markdown]
# Before we start training, we need to gather and label images that will be used for training the object detection model. A good starting point for a proof-of-concept model is 200 images. The training images should have random objects in the image along with the desired objects, and should have a variety of backgrounds and lighting conditions.
#
# There are a couple options for gathering images:
#
#
# *   Build a custom dataset by taking your own pictures of the objects and labeling them (this typically results in the best performance)
# *   Find a pre-made dataset from sources like [Roboflow Universe](), [Kaggle](), or [Google Images V7]()
#
#
# If you want to build your own dataset, there are several tools available for labeling images. One good option is [Label Studio](https://labelstud.io/?utm_source=youtube&utm_medium=video&utm_campaign=edjeelectronics), a free and open-source labeling tool that has a simple workflow while providing capabilities for more advanced features. My YouTube video that walks through this notebook (link to be added soon) shows how to label images with Label Studio.
#
# <p align=center>
# <img src="https://raw.githubusercontent.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/refs/heads/main/doc/label-studio-example.PNG" height="380"><br>
# <i>Example of a candy image labeled with Label Studio.</i>
# </p>
#
# If you used Label Studio to label and export the images, they'll be exported in a `project.zip` file that contains the following:
#
# - An `images` folder containing the images
# - A `labels` folder containing the labels in YOLO annotation format
# - A `classes.txt` labelmap file that contains all the classes
# - A `notes.json` file that contains info specific to Label Studio (this file can be ignored)
#
# If you obtained your dataset from another source (like Roboflow Universe) or used another tool to label your dataset, make sure the files are organized in the same folder structure.
#
# <p align=center>
# <img src="https://raw.githubusercontent.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/refs/heads/main/doc/zipped-data-example.png" height=""><br>
# <i>Organize your data in the folders shown here. See my <a href="https://s3.us-west-1.amazonaws.com/evanjuras.com/resources/candy_data_06JAN25.zip">Candy Detection Dataset</a> for an example.</i>
# </p>
#
# Once you've got your dataset built, put into the file structure shown above, and zipped into `data.zip`, you're ready to move on to the next step.

# %% [markdown]
# # 2.&nbsp;Upload Image Dataset and Prepare Training Data

# %% [markdown]
# Next, we'll upload our dataset and prepare it for training with YOLO. We'll split the dataset into train and validation folders, and we'll automatically generate the configuration file for training the model.

# %% [markdown]
# ## 2.1 Upload images
#
# First, we need to upload the dataset to Colab. Here are a few options for moving the `data.zip` folder into this Colab instance.

# %% [markdown]
# **Option 1. Upload through Google Colab**
#
# Upload the `data.zip` file to the Google Colab instance by clicking the "Files" icon on the left hand side of the browser, and then the "Upload to session storage" icon. Select the zip folder to upload it.
#
# <p>
# <br>
# <img src="https://raw.githubusercontent.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/refs/heads/main/doc/upload-colab-files.png" height="240">
# </p>

# %% [markdown]
# **Option 2. Copy from Google Drive**
#
# You can also upload your images to your personal Google Drive, mount the drive on this Colab session, and copy them over to the Colab filesystem. This option works well if you want to upload the images beforehand so you don't have to wait for them to upload each time you restart this Colab. If you have more than 50MB worth of images, I recommend using this option.
#
# First, upload the `data.zip` file to your Google Drive, and make note of the folder you uploaded them to. Replace `MyDrive/path/to/data.zip` with the path to your zip file. (For example, I uploaded the zip file to folder called "candy-dataset1", so I would use `MyDrive/candy-dataset1/data.zip` for the path). Then, run the following block of code to mount your Google Drive to this Colab session and copy the folder to this filesystem.

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# !cp /content/gdrive/MyDrive/path/to/data.zip /content

# %% [markdown]
# **Option 3. Use my candy detection or coin detection dataset**
#
# If you just want to test the process on a pre-made dataset, you can use one of my datasets:
#
# *   [Candy image dataset](https://s3.us-west-1.amazonaws.com/evanjuras.com/resources/candy_data_14DEC24.zip), which contains 162 pictures of popular candies (Skittles, Snickers, etc)
# *   [Coin image dataset](https://s3.us-west-1.amazonaws.com/evanjuras.com/resources/YOLO_coin_data_12DEC30.zip), which contains 750 pictures of US coins (pennies, dimes, nickels, and quarters)
#
# Download one of the datasets by running the following code block. I'll use the candy detection dataset as the example for the rest of the notebook.

# %%
# To use my one of pre-made dataset instead of your own custom dataset, download it here (control which dataset is downloaded by commenting out either line)
# !wget -O /content/data.zip https://s3.us-west-1.amazonaws.com/evanjuras.com/resources/candy_data_06JAN25.zip # Candy dataset
#!wget -O /content/data.zip https://s3.us-west-1.amazonaws.com/evanjuras.com/resources/YOLO_coin_data_12DEC30.zip # Coin dataset

# %% [markdown]
# ## 2.2 Split images into train and validation folders

# %% [markdown]
# At this point, whether you used Option 1, 2, or 3, you should be able to click the folder icon on the left and see your `data.zip` file in the list of files. Next, we'll unzip `data.zip` and create some folders to hold the images. Run the following code block to unzip the data.

# %%
# Unzip images to a custom data folder
# !unzip -q /content/data.zip -d /content/custom_data
# Out:
# replace /content/custom_data/data/classes.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %% [markdown]
# Ultralytics requires a particular folder structure to store training data for models. Ultralytics requires a particular folder structure to store training data for models. The root folder is named “data”. Inside, there are two main folders:
#
# *   **Train**: These are the actual images used to train the model. In one epoch of training, every image in the train set is passed into the neural network. The training algorithm adjusts the network weights to fit the data in the images.
#
#
# *   **Validation**: These images are used to check the model's performance at the end of each training epoch.
#
# In each of these folders is a “images” folder and a “labels” folder, which hold the image files and annotation files respectively.

# %% [markdown]
# I wrote a Python script that will automatically create the required folder structure and randomly move 90% of dataset to the "train" folder and 10% to the "validation" folder. Run the following code block to download and execute the scrpt.

# %%
# !wget -O /content/train_val_split.py https://raw.githubusercontent.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/refs/heads/main/utils/train_val_split.py

# TO DO: Improve robustness of train_val_split.py script so it can handle nested data folders, etc
# !python train_val_split.py --datapath="/content/custom_data/data" --train_pct=0.9
# Out:
# --2026-06-27 00:19:55--  https://raw.githubusercontent.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/refs/heads/main/utils/train_val_split.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3203 (3.1K) [text/plain]
# Saving to: ‘/content/train_val_split.py’
#
# /content/train_val_ 100%[===================>]   3.13K  --.-KB/s    in 0s
#
# 2026-06-27 00:19:55 (62.8 MB/s) - ‘/content/train_val_split.py’ saved [3203/3203]
#
# Number of image files: 876
# Number of annotation files: 876
# Images moving to train: 788
# Images moving to validation: 88

# %% [markdown]
# # 3.&nbsp;Install Requirements (Ultralytics)
#
# Next, we'll install the Ultralytics library in this Google Colab instance. This Python library will be used to train the YOLO model.

# %%
# !pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.4.80-py3-none-any.whl.metadata (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.0/41.0 kB 4.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (4.13.0.92)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.11.0+cu128)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (0.26.0+cu128)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: polars>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.35.2)
# Requirement already satisfied: nvidia-ml-py>=12.0.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (13.610.43)
# Collecting ultralytics-thop>=2.0.18 (from ultralytics)
#   Downloading ultralytics_thop-2.0.20-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (26.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: polars-runtime-32==1.35.2 in /usr/local/lib/python3.12/dist-packages (from polars>=0.20.0->ultralytics) (1.35.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2026.5.20)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.29.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings<13,>=12.9.4->torch>=1.8.0->ultralytics) (1.5.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Downloading ultralytics-8.4.80-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 70.6 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.20-py3-none-any.whl (28 kB)
# Installing collected packages: ultralytics-thop, ultralytics
# Successfully installed ultralytics-8.4.80 ultralytics-thop-2.0.20

# %% [markdown]
# # 4.&nbsp;Configure Training

# %% [markdown]
# There's one last step before we can run training: we need to create the Ultralytics training configuration YAML file. This file specifies the location of your train and validation data, and it also defines the model's classes. An example configuration file model is available [here](https://github.com/ultralytics/ultralytics/blob/main/ultralytics/cfg/datasets/coco128.yaml).
#
# Run the code block below to automatically generate a `data.yaml` configuration file. Make sure you have a labelmap file located at `custom_data/classes.txt`. If you used Label Studio or one of my pre-made datasets, it should already be present. If you assembled the dataset another way, you may have to manually create the `classes.txt` file (see [here](https://github.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/blob/main/doc/classes.txt) for an example of how it's formatted).

# %%
# Python function to automatically create data.yaml config file
# 1. Reads "classes.txt" file to get list of class names
# 2. Creates data dictionary with correct paths to folders, number of classes, and names of classes
# 3. Writes data in YAML format to data.yaml

import yaml
import os

def create_data_yaml(path_to_classes_txt, path_to_data_yaml):

  # Read class.txt to get class names
  if not os.path.exists(path_to_classes_txt):
    print(f'classes.txt file not found! Please create a classes.txt labelmap and move it to {path_to_classes_txt}')
    return
  with open(path_to_classes_txt, 'r') as f:
    classes = []
    for line in f.readlines():
      if len(line.strip()) == 0: continue
      classes.append(line.strip())
  number_of_classes = len(classes)

  # Create data dictionary
  data = {
      'path': '/content/data',
      'train': 'train/images',
      'val': 'validation/images',
      'nc': number_of_classes,
      'names': classes
  }

  # Write data to YAML file
  with open(path_to_data_yaml, 'w') as f:
    yaml.dump(data, f, sort_keys=False)
  print(f'Created config file at {path_to_data_yaml}')

  return

# Define path to classes.txt and run function
path_to_classes_txt = '/content/custom_data/data/classes.txt'
path_to_data_yaml = '/content/data.yaml'

create_data_yaml(path_to_classes_txt, path_to_data_yaml)

print('\nFile contents:\n')
# !cat /content/data.yaml
# Out:
# Created config file at /content/data.yaml
#
# File contents:
#
# path: /content/data
# train: train/images
# val: validation/images
# nc: 5
# names:
# - broken_door_lock
# - damaged_warning_sign
# - mold_damp_wall
# - obstruction_walkway
# - overflowing_trash_bin

# %% [markdown]
# # 5.&nbsp;Train Model

# %% [markdown]
# ## 5.1 Training Parameters
# Now that the data is organized and the config file is created, we're ready to start training! First, there are a few important parameters to decide on. Visit my article on [Training YOLO Models Locally](https://www.ejtech.io/learn/train-yolo-models) to learn more about these parameters and how to choose them.
#
# **Model architecture & size (`model`):**
#
# There are several YOLO11 models sizes available to train, including `yolo11n.pt`, `yolo11s.pt`, `yolo11m.pt`, `yolo11l.pt`, and `yolo11xl.pt`. Larger models run slower but have higher accuracy, while smaller models run faster but have lower accuracy. I made a brief YouTube video that compares performance of different YOLO models on a Raspberry Pi 5 and a laptop with a RTX 4050 GPU, [check it out here to get a sense of their speed accuracy](https://youtu.be/_WKS4E9SmkA). If you aren't sure which model size to use, `yolo11s.pt` is a good starting point.
#
# You can also train YOLOv8 or YOLOv5 models by substituting `yolo11` for `yolov8` or `yolov5`.
#
#
# **Number of epochs (`epochs`)**
#
# In machine learning, one “epoch” is one single pass through the full training dataset. Setting the number of epochs dictates how long the model will train for. The best amount of epochs to use depends on the size of the dataset and the model architecture. If your dataset has less than 200 images, a good starting point is 60 epochs. If your dataset has more than 200 images, a good starting point is 40 epochs.
#
#
# **Resolution (`imgsz`)**
#
# Resolution has a large impact on the speed and accuracy of the model: a lower resolution model will have higher speed but less accuracy. YOLO models are typically trained and inferenced at a 640x640 resolution. However, if you want your model to run faster or know you will be working with low-resolution images, try using a lower resolution like 480x480.

# %% [markdown]
# ## 5.2 Run Training!

# %% [markdown]
# Run the following code block to begin training. If you want to use a different model, number of epochs, or resolution, change `model`, `epochs`, or `imgsz`.

# %%
# !yolo detect train data=/content/data.yaml model=yolo11s.pt epochs=60 imgsz=640
# Out:
# Ultralytics 8.4.80 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dis=6.0, distill_model=None, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=60, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11s.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=train-5, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, quantize=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/content/runs/detect/train-5, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=tracktrack.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=5
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    443776  ultralytics.nn.modules.block.C3k2            [768, 256, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    127680  ultralytics.nn.modules.block.C3k2            [512, 128, 1, False]
#  17                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    345472  ultralytics.nn.modules.block.C3k2            [384, 256, 1, False]
#  20                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  23        [16, 19, 22]  1    821343  ultralytics.nn.modules.head.Detect           [5, 16, None, [128, 256, 512]]
# YOLO11s summary: 182 layers, 9,429,727 parameters, 9,429,711 gradients, 21.6 GFLOPs
#
# Transferred 493/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1156.4±385.8 MB/s, size: 65.0 KB)
# train: Scanning /content/data/train/labels... 788 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 788/788 2.0Kit/s 0.4s
# train: New cache created: /content/data/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.1±0.1 ms, read: 474.1±136.3 MB/s, size: 71.6 KB)
# val: Scanning /content/data/validation/labels... 88 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 88/88 1.4Kit/s 0.1s
# val: New cache created: /content/data/validation/labels.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001111, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Plotting labels to /content/runs/detect/train-5/labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /content/runs/detect/train-5
# Starting training for 60 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/60       4.1G     0.9005      2.119        1.4         14        640: 100% ━━━━━━━━━━━━ 50/50 1.4it/s 35.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.8s/it 8.5s
#                    all         88         88      0.643      0.705      0.736      0.477
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/60      5.29G     0.8726        1.1      1.386         13        640: 100% ━━━━━━━━━━━━ 50/50 3.2it/s 15.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.9it/s 1.0s
#                    all         88         88       0.59      0.817      0.737      0.423
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/60      5.31G     0.9012     0.9785      1.401          9        640: 100% ━━━━━━━━━━━━ 50/50 3.1it/s 16.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.5it/s 1.2s
#                    all         88         88      0.541      0.523      0.454      0.187
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/60      5.31G     0.9406      1.046      1.428         11        640: 100% ━━━━━━━━━━━━ 50/50 3.3it/s 15.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.6it/s 1.1s
#                    all         88         88      0.573      0.786      0.693      0.432
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/60      5.31G     0.8997     0.9096      1.421         13        640: 100% ━━━━━━━━━━━━ 50/50 3.2it/s 15.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.6it/s 1.1s
#                    all         88         88      0.423      0.728      0.564      0.328
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/60      5.31G     0.8768     0.8981      1.382         16        640: 100% ━━━━━━━━━━━━ 50/50 3.0it/s 16.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.2it/s 1.4s
#                    all         88         88      0.656      0.685      0.643      0.365
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/60      5.31G     0.8515     0.8872      1.375         15        640: 100% ━━━━━━━━━━━━ 50/50 3.2it/s 15.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.4it/s 1.3s
#                    all         88         88      0.746      0.578      0.716      0.449
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/60      5.31G        0.9     0.9158      1.392         11        640: 100% ━━━━━━━━━━━━ 50/50 3.2it/s 15.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.5it/s 1.2s
#                    all         88         88       0.68      0.736      0.708      0.462
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/60      5.31G     0.8258     0.8471      1.356         14        640: 100% ━━━━━━━━━━━━ 50/50 3.1it/s 16.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.1it/s 1.4s
#                    all         88         88      0.878      0.697      0.771      0.535
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/60      5.31G     0.8187     0.8153      1.336         12        640: 100% ━━━━━━━━━━━━ 50/50 3.3it/s 15.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.7it/s 1.1s
#                    all         88         88      0.879       0.81      0.898      0.613
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/60      5.31G     0.8038     0.8173      1.348          8        640: 100% ━━━━━━━━━━━━ 50/50 3.2it/s 15.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.8it/s 1.1s
#                    all         88         88      0.886      0.768      0.884      0.625
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/60      5.31G     0.8261     0.7979      1.355         14        640: 100% ━━━━━━━━━━━━ 50/50 3.2it/s 15.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         88         88      0.861      0.751       0.84       0.64
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/60      5.31G     0.8158     0.7838      1.338          8        640: 100% ━━━━━━━━━━━━ 50/50 3.2it/s 15.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.8it/s 1.1s
#                    all         88         88      0.881      0.801       0.84      0.647
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/60      5.31G     0.7814     0.7848      1.315         13        640: 100% ━━━━━━━━━━━━ 50/50 3.2it/s 15.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 3.4it/s 0.9s
#                    all         88         88      0.854      0.806      0.859      0.641
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/60      5.31G     0.7352     0.7217      1.278         16        640: 100% ━━━━━━━━━━━━ 50/50 3.2it/s 15.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.1it/s 1.4s
#                    all         88         88      0.876      0.916      0.926      0.661
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/60      5.31G     0.8083     0.7699      1.322         11        640: 100% ━━━━━━━━━━━━ 50/50 3.2it/s 15.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 3.2it/s 1.0s
#                    all         88         88      0.878      0.872      0.916      0.672
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/60      5.31G     0.7406     0.7249      1.302         10        640: 100% ━━━━━━━━━━━━ 50/50 3.2it/s 15.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 3.1it/s 1.0s
#                    all         88         88      0.887      0.863      0.921      0.633
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/60      5.31G      0.743     0.6963      1.277         13        640: 100% ━━━━━━━━━━━━ 50/50 3.2it/s 15.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         88         88      0.894      0.842      0.894      0.663
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/60      5.31G     0.7105     0.6751      1.262         14        640: 100% ━━━━━━━━━━━━ 50/50 3.3it/s 15.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 3.1it/s 1.0s
#                    all         88         88      0.866      0.929      0.931      0.657
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/60      5.31G     0.7433     0.7059      1.304         13        640: 100% ━━━━━━━━━━━━ 50/50 3.2it/s 15.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 3.3it/s 0.9s
#                    all         88         88      0.821      0.832      0.843      0.553
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/60      5.31G     0.7374      0.695      1.286         12        640: 100% ━━━━━━━━━━━━ 50/50 3.2it/s 15.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.3it/s 1.3s
#                    all         88         88      0.936      0.919       0.96      0.722
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/60      5.31G      0.695     0.6287      1.255         16        640: 100% ━━━━━━━━━━━━ 50/50 3.2it/s 15.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.6it/s 1.2s
#                    all         88         88      0.939      0.963      0.966      0.703
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/60      5.31G     0.7058     0.6194      1.247         12        640: 100% ━━━━━━━━━━━━ 50/50 3.2it/s 15.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 3.0it/s 1.0s
#                    all         88         88      0.856      0.912      0.894      0.707
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/60      5.31G      0.701     0.6328      1.257          8        640: 100% ━━━━━━━━━━━━ 50/50 3.2it/s 15.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 3.5it/s 0.9s
#                    all         88         88      0.883      0.905      0.932      0.731
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/60      5.31G     0.7209     0.6326      1.267         11        640: 100% ━━━━━━━━━━━━ 50/50 3.1it/s 15.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.5it/s 1.2s
#                    all         88         88      0.929      0.909      0.953      0.694
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/60      5.31G     0.6903     0.6162      1.238         14        640: 100% ━━━━━━━━━━━━ 50/50 3.2it/s 15.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 3.4it/s 0.9s
#                    all         88         88      0.892      0.944      0.947      0.673
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/60      5.31G     0.7089     0.6463      1.246         12        640: 100% ━━━━━━━━━━━━ 50/50 3.2it/s 15.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 3.3it/s 0.9s
#                    all         88         88      0.857      0.941      0.964      0.658
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/60      5.31G     0.6926     0.6048      1.238         13        640: 100% ━━━━━━━━━━━━ 50/50 3.2it/s 15.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.8it/s 1.6s
#                    all         88         88      0.826      0.829       0.88      0.663
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/60      5.31G     0.6558      0.587      1.217         14        640: 100% ━━━━━━━━━━━━ 50/50 3.2it/s 15.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.9it/s 1.0s
#                    all         88         88      0.938      0.923      0.965      0.754
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/60      5.31G     0.6631     0.5647      1.213         13        640: 100% ━━━━━━━━━━━━ 50/50 3.2it/s 15.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 3.3it/s 0.9s
#                    all         88         88      0.955      0.922       0.96      0.738
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/60      5.31G     0.6698     0.5861      1.214         13        640: 100% ━━━━━━━━━━━━ 50/50 3.2it/s 15.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.2it/s 1.4s
#                    all         88         88       0.95      0.945      0.966      0.749
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/60      5.31G     0.6417      0.541      1.206         15        640: 100% ━━━━━━━━━━━━ 50/50 3.3it/s 15.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.9it/s 1.0s
#                    all         88         88       0.88      0.883      0.958      0.726
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/60      5.31G     0.6519     0.5997        1.2         13        640: 100% ━━━━━━━━━━━━ 50/50 3.3it/s 15.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 3.2it/s 0.9s
#                    all         88         88      0.936      0.945      0.951      0.786
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/60      5.31G      0.627     0.5553      1.186         11        640: 100% ━━━━━━━━━━━━ 50/50 3.2it/s 15.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.4it/s 1.3s
#                    all         88         88      0.952      0.963      0.971      0.805
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/60      5.31G     0.6291     0.5725      1.194         12        640: 100% ━━━━━━━━━━━━ 50/50 3.2it/s 15.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.9it/s 1.0s
#                    all         88         88      0.951      0.963      0.956      0.784
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/60      5.31G     0.6547     0.5502      1.209         11        640: 100% ━━━━━━━━━━━━ 50/50 3.3it/s 15.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.8it/s 1.1s
#                    all         88         88      0.955      0.971      0.984      0.793
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/60      5.31G     0.6494     0.5237      1.205         12        640: 100% ━━━━━━━━━━━━ 50/50 3.2it/s 15.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 3.4it/s 0.9s
#                    all         88         88      0.936      0.948      0.976      0.785
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/60      5.31G     0.6301      0.561      1.187         13        640: 100% ━━━━━━━━━━━━ 50/50 3.2it/s 15.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.6it/s 1.2s
#                    all         88         88       0.92      0.945      0.969       0.78
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/60      5.31G     0.6061     0.5252      1.179         14        640: 100% ━━━━━━━━━━━━ 50/50 3.2it/s 15.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 3.1it/s 1.0s
#                    all         88         88      0.915      0.961      0.949      0.768
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/60      5.31G     0.6306     0.5247      1.192         13        640: 100% ━━━━━━━━━━━━ 50/50 3.2it/s 15.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.9it/s 1.0s
#                    all         88         88      0.944      0.954      0.964       0.79
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/60      5.31G     0.6423     0.5301      1.192         15        640: 100% ━━━━━━━━━━━━ 50/50 3.1it/s 16.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         88         88      0.938      0.956      0.968      0.782
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/60      5.31G      0.636     0.5353      1.187         14        640: 100% ━━━━━━━━━━━━ 50/50 3.2it/s 15.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.9it/s 1.0s
#                    all         88         88      0.961      0.954      0.973      0.777
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/60      5.31G     0.5947       0.48       1.17         14        640: 100% ━━━━━━━━━━━━ 50/50 3.2it/s 15.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 3.3it/s 0.9s
#                    all         88         88      0.977      0.967      0.963      0.761
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/60      5.31G     0.5957     0.4992      1.156         11        640: 100% ━━━━━━━━━━━━ 50/50 3.0it/s 16.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.1it/s 1.5s
#                    all         88         88      0.929      0.971      0.967      0.793
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/60      5.31G      0.599     0.4909      1.169         14        640: 100% ━━━━━━━━━━━━ 50/50 3.2it/s 15.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 3.4it/s 0.9s
#                    all         88         88      0.946      0.948      0.977      0.783
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/60      5.31G     0.5761     0.4706      1.142         10        640: 100% ━━━━━━━━━━━━ 50/50 3.2it/s 15.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.7it/s 1.1s
#                    all         88         88      0.964      0.952      0.976      0.791
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/60      5.31G     0.6016     0.4891      1.161         10        640: 100% ━━━━━━━━━━━━ 50/50 3.2it/s 15.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.1it/s 1.4s
#                    all         88         88      0.973      0.964      0.986      0.805
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/60      5.31G     0.5769     0.4708      1.144         13        640: 100% ━━━━━━━━━━━━ 50/50 3.2it/s 15.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 3.4it/s 0.9s
#                    all         88         88      0.953      0.952      0.983        0.8
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/60      5.31G     0.5811     0.4669      1.142         15        640: 100% ━━━━━━━━━━━━ 50/50 3.2it/s 15.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 3.2it/s 0.9s
#                    all         88         88      0.971      0.972      0.987      0.806
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/60      5.31G     0.5736     0.4579      1.141          9        640: 100% ━━━━━━━━━━━━ 50/50 3.2it/s 15.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.7it/s 1.1s
#                    all         88         88      0.948       0.97      0.982      0.809
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       51/60      5.31G     0.5754     0.4852      1.309          4        640: 100% ━━━━━━━━━━━━ 50/50 2.9it/s 17.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 3.6it/s 0.8s
#                    all         88         88      0.967      0.963      0.988      0.809
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       52/60      5.31G     0.5089     0.3414      1.247          4        640: 100% ━━━━━━━━━━━━ 50/50 3.4it/s 14.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 3.4it/s 0.9s
#                    all         88         88      0.979      0.963      0.987      0.803
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       53/60      5.31G     0.4855      0.316      1.236          4        640: 100% ━━━━━━━━━━━━ 50/50 3.4it/s 14.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 3.2it/s 0.9s
#                    all         88         88      0.941      0.973      0.989      0.804
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       54/60      5.31G     0.4691     0.3147      1.193          4        640: 100% ━━━━━━━━━━━━ 50/50 3.2it/s 15.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 3.2it/s 0.9s
#                    all         88         88      0.971      0.971       0.99       0.83
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       55/60      5.31G     0.4809     0.3095       1.21          4        640: 100% ━━━━━━━━━━━━ 50/50 3.3it/s 15.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 3.5it/s 0.9s
#                    all         88         88      0.957      0.973      0.987      0.824
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       56/60      5.31G      0.481     0.2932      1.208          4        640: 100% ━━━━━━━━━━━━ 50/50 3.2it/s 15.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 3.4it/s 0.9s
#                    all         88         88      0.967      0.973      0.987      0.827
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       57/60      5.31G     0.4987     0.3021      1.216          4        640: 100% ━━━━━━━━━━━━ 50/50 3.3it/s 15.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.4it/s 1.2s
#                    all         88         88      0.954      0.968      0.992      0.841
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       58/60      5.31G     0.4591     0.2903      1.177          4        640: 100% ━━━━━━━━━━━━ 50/50 3.3it/s 15.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 3.6it/s 0.8s
#                    all         88         88       0.97      0.966      0.985      0.828
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       59/60      5.31G     0.4322     0.2636      1.157          4        640: 100% ━━━━━━━━━━━━ 50/50 3.3it/s 15.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 3.6it/s 0.8s
#                    all         88         88      0.966      0.971      0.985      0.832
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       60/60      5.31G     0.4409     0.2696      1.151          4        640: 100% ━━━━━━━━━━━━ 50/50 3.3it/s 15.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 3.3it/s 0.9s
#                    all         88         88       0.97      0.976      0.987      0.835
#
# 60 epochs completed in 0.296 hours.
# Optimizer stripped from /content/runs/detect/train-5/weights/last.pt, 19.2MB
# Optimizer stripped from /content/runs/detect/train-5/weights/best.pt, 19.2MB
#
# Validating /content/runs/detect/train-5/weights/best.pt...
# Ultralytics 8.4.80 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO11s summary (fused): 101 layers, 9,414,735 parameters, 0 gradients, 21.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.6it/s 1.9s
#                    all         88         88      0.954      0.968      0.992      0.841
#       broken_door_lock         17         17      0.992          1      0.995      0.767
#   damaged_warning_sign         23         23      0.993          1      0.995      0.865
#         mold_damp_wall         23         23          1      0.898      0.992      0.721
#    obstruction_walkway         18         18      0.927      0.944      0.982      0.962
#  overflowing_trash_bin          7          7      0.856          1      0.995      0.889
# Speed: 0.2ms preprocess, 6.3ms inference, 0.0ms loss, 5.1ms postprocess per image
# Results saved to /content/runs/detect/train-5
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %% [markdown]
# The training algorithm will parse the images in the training and validation directories and then start training the model. At the end of each training epoch, the program runs the model on the validation dataset and reports the resulting mAP, precision, and recall. As training continues, the mAP should generally increase with each epoch. Training will end once it goes through the number of epochs specified by `epochs`.
#
# > **NOTE:** Make sure to allow training to run to completion, because an optimizer runs at the end of training that strips out unneeded layers from the model.
#
# The best trained model weights will be saved in `content/runs/detect/train/weights/best.pt`. Additional information about training is saved in the `content/runs/detect/train` folder, including a `results.png` file that shows how loss, precision, recall, and mAP progressed over each epoch.

# %% [markdown]
# #6.&nbsp;Test Model

# %% [markdown]
# The model has been trained; now it's time to test it! The commands below run the model on the images in the validation folder and then display the results for the first 10 images. This is a good way to confirm your model is working as expected. Click Play on the blocks below to see how your model performs.

# %%
# !yolo detect predict model=runs/detect/train-5/weights/best.pt source=data/validation/images save=True
# Out:
# Ultralytics 8.4.80 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO11s summary (fused): 101 layers, 9,414,735 parameters, 0 gradients, 21.3 GFLOPs
#
# image 1/88 /content/data/validation/images/00ce1be7-image_172_jpeg.rf.b6c6ff7c4aba41f73c1a7432d2627b1e.jpg: 640x608 2 overflowing_trash_bins, 52.8ms
# image 2/88 /content/data/validation/images/0235b80b-1-77-_jpg.rf.d4e5da02f1cf903c937ca2abbbf44111.jpg: 640x640 1 mold_damp_wall, 16.2ms
# image 3/88 /content/data/validation/images/04983233-image8-5-_jpeg_jpg.rf.0a6ddb527bee8ec9a9cbeb44af4c313e.jpg: 640x640 1 damaged_warning_sign, 15.4ms
# image 4/88 /content/data/validation/images/04d303f5-Merge_mp4-88_jpg.rf.14610595016bb45c157a593f83d25ac5.jpg: 640x640 1 obstruction_walkway, 15.4ms
# image 5/88 /content/data/validation/images/081aed5f-IMG_8117_jpg.rf.bad1b091183040db6101bc020cc3046f.jpg: 640x640 1 damaged_warning_sign, 15.4ms
# image 6/88 /content/data/validation/images/0a05f149-Merge_mp4-47_jpg.rf.4cc8ad9b94f7d9264ac9800da0e15321.jpg: 640x640 1 obstruction_walkway, 15.5ms
# image 7/88 /content/data/validation/images/0a94c0a7-1-184-_jpg.rf.71e5ec09d22abd9d37de718c2c63253b.jpg: 640x640 1 mold_damp_wall, 15.4ms
# image 8/88 /content/data/validation/images/0d7a7b83-image_154_jpeg.rf.81d9a66c7453f358f111d7d7bbebe748.jpg: 640x448 1 overflowing_trash_bin, 50.3ms
# image 9/88 /content/data/validation/images/0e2d3dbf-1-58-_jpg.rf.7c921ec5f40756de0bae4e342d93325e.jpg: 640x640 1 mold_damp_wall, 16.0ms
# image 10/88 /content/data/validation/images/0e53b159-Merge_mp4-73_jpg.rf.c85a6692b2531d6c47a799384dc2c245.jpg: 640x640 1 obstruction_walkway, 15.4ms
# image 11/88 /content/data/validation/images/178514ab-Merge_mp4-85_jpg.rf.2f3fefa03b952b67959d8e1349e7323b.jpg: 640x640 1 obstruction_walkway, 15.5ms
# image 12/88 /content/data/validation/images/17c67aa3-graffiti_highway_sign-thumb-640xau_qhO60rM.rf.d5d694ed34bfc0d4453419a17b70661b.jpg: 640x640 1 damaged_warning_sign, 15.4ms
# image 13/88 /content/data/validation/images/1adeefda-1-189-_jpg.rf.d9ac76e3c6549508b0dcffda806c8d88.jpg: 640x640 1 mold_damp_wall, 11.4ms
# image 14/88 /content/data/validation/images/21683384-IMG_8121_jpg.rf.9b649ef8eb594efc7dd6da3c356e14fd.jpg: 640x640 1 damaged_warning_sign, 12.8ms
# image 15/88 /content/data/validation/images/237c95af-1-45-_jpg.rf.34c368c2817d720a10a79a3c19512d57.jpg: 640x640 1 mold_damp_wall, 11.5ms
# image 16/88 /content/data/validation/images/2a69331c-1-59-_jpg.rf.5abfa621cd6c659c10542ace5a02a1a9.jpg: 640x640 1 mold_damp_wall, 11.4ms
# image 17/88 /content/data/validation/images/2b8ce25b-IMG_8099_jpg.rf.20149160006ee46d27e8ef76645f98df.jpg: 640x640 1 damaged_warning_sign, 11.4ms
# image 18/88 /content/data/validation/images/31534513-Merge_mp4-29_jpg.rf.b5afe3f18e3568d0bb02c5058a5f5f67.jpg: 640x640 1 obstruction_walkway, 11.4ms
# image 19/88 /content/data/validation/images/3314d711-1-190-_jpg.rf.081a93ded0dac826850ce98b8d7a2a20.jpg: 640x640 1 mold_damp_wall, 11.4ms
# image 20/88 /content/data/validation/images/37226389-image_90_jpeg.rf.1fe7e8778eaa3135b7b41ed19009ac8e.jpg: 448x640 1 overflowing_trash_bin, 53.4ms
# image 21/88 /content/data/validation/images/38dbecff-1-154-_jpg.rf.b187e6840309c73575639ab296e4fb5e.jpg: 640x640 1 mold_damp_wall, 11.7ms
# image 22/88 /content/data/validation/images/3ac86af7-Merge_mp4-44_jpg.rf.ac13b8fac6d61dd5ee0a3230703fc693.jpg: 640x640 1 obstruction_walkway, 10.4ms
# image 23/88 /content/data/validation/images/3bbf0be9-1-166-_jpg.rf.da37d868095d7ce72ca59fc012e0a57d.jpg: 640x640 1 mold_damp_wall, 10.5ms
# image 24/88 /content/data/validation/images/3c20c658-1-157-_jpg.rf.ad092a962d3f625fba89bc37fc9ce3cb.jpg: 640x640 1 mold_damp_wall, 10.5ms
# image 25/88 /content/data/validation/images/3d2ca406-IMG_8123_jpg.rf.13a22a8b704a99a29f953f442e6e4990.jpg: 640x640 1 damaged_warning_sign, 10.5ms
# image 26/88 /content/data/validation/images/3e61c8e4-image_80_jpeg.rf.3d80fac4fe22f0afe76672c28786ece6.jpg: 448x640 1 overflowing_trash_bin, 8.7ms
# image 27/88 /content/data/validation/images/3f173752-1-43-_jpg.rf.9d95ccf6e65cf5189c0ff5897db8ebce.jpg: 640x640 1 mold_damp_wall, 11.7ms
# image 28/88 /content/data/validation/images/43157a81-image10-2-_jpeg_jpg.rf.68bd9a7cd4720dc8434e0481d04f478c.jpg: 640x640 1 damaged_warning_sign, 10.3ms
# image 29/88 /content/data/validation/images/43601724-Merge_mp4-30_jpg.rf.83e8490658be872a0d0d1153a4d4f8de.jpg: 640x640 1 obstruction_walkway, 10.3ms
# image 30/88 /content/data/validation/images/4a41fb8e-open_2_qt_mov-0005_jpg.rf.47afc0b6d053f06e26129c91819d5eb9.jpg: 384x640 1 broken_door_lock, 54.6ms
# image 31/88 /content/data/validation/images/4f5a3f60-Merge_mp4-43_jpg.rf.67add928037cc00cdfcdb8ab3ef8bace.jpg: 640x640 1 obstruction_walkway, 9.6ms
# image 32/88 /content/data/validation/images/4f886495-1-109-_jpg.rf.398b75bd90d321c88be47bb7538bb5f3.jpg: 640x640 1 mold_damp_wall, 12.4ms
# image 33/88 /content/data/validation/images/5e163958-open_2_qt_mov-0014_jpg.rf.56bcc0d22d11ac668e01cb1e353f9735.jpg: 384x640 1 broken_door_lock, 14.2ms
# image 34/88 /content/data/validation/images/5faa7f30-1-158-_jpg.rf.971f39776f4a0b488a900e6bb7843070.jpg: 640x640 1 mold_damp_wall, 14.0ms
# image 35/88 /content/data/validation/images/662e4d44-1-94-_jpg.rf.e7c9093e171b5357010718cb56f3d62b.jpg: 640x640 1 mold_damp_wall, 10.4ms
# image 36/88 /content/data/validation/images/691c1137-IMG_8083_jpg.rf.cd2beab2da7a3e4c1488166d0b8afcad.jpg: 640x640 1 damaged_warning_sign, 8.8ms
# image 37/88 /content/data/validation/images/699684f3-unfocused__closed_qt_mov-0005_jpg.rf.d929e5fea587fea4d2a7f0409b248a22.jpg: 384x640 1 broken_door_lock, 11.0ms
# image 38/88 /content/data/validation/images/69b10d28-Capture3_JPG_jpg.rf.1e29539db2e02a475f1bb9042c093261.jpg: 640x640 1 damaged_warning_sign, 9.4ms
# image 39/88 /content/data/validation/images/6b823c2a-IMG_8070_jpg.rf.2fb2e9e6cc2a5c635c4f9ce40f42f338.jpg: 640x640 1 damaged_warning_sign, 8.8ms
# image 40/88 /content/data/validation/images/6cc59073-Merge_mp4-38_jpg.rf.8b57666e84a16e71a1e7107c2cb2b961.jpg: 640x640 1 obstruction_walkway, 8.8ms
# image 41/88 /content/data/validation/images/6d278bab-night_qt_mov-0029_jpg.rf.1591bcdebe83eb06c88bc6526a427f1f.jpg: 384x640 1 broken_door_lock, 7.7ms
# image 42/88 /content/data/validation/images/71c72e8e-24_jpg.rf.61ce70b9ddb0a99bd338ce8cbd644f0c.jpg: 640x640 1 broken_door_lock, 9.5ms
# image 43/88 /content/data/validation/images/760c3d20-night_qt_mov-0024_jpg.rf.01610e9eb75eb97f7654b3556b08139f.jpg: 384x640 1 broken_door_lock, 8.2ms
# image 44/88 /content/data/validation/images/7a180fa9-open_qt_mov-0000_jpg.rf.1b01484a9b12ec09d6fd3eb21f9cbcc1.jpg: 384x640 1 broken_door_lock, 7.2ms
# image 45/88 /content/data/validation/images/7c4fd037-night_qt_mov-0020_jpg.rf.edff89ca6470f80443e72befaee02b33.jpg: 384x640 1 broken_door_lock, 7.4ms
# image 46/88 /content/data/validation/images/8165a697-1-153-_jpg.rf.5effc5915f133297accda921075e67aa.jpg: 640x640 1 mold_damp_wall, 9.4ms
# image 47/88 /content/data/validation/images/82886c8f-1-104-_jpg.rf.829cc7da2a105714c74b28a011db1a00.jpg: 640x640 1 mold_damp_wall, 8.8ms
# image 48/88 /content/data/validation/images/839b418e-22_jpg.rf.af1f17b1ace8245111973eaf1cc6e29c.jpg: 640x640 1 broken_door_lock, 8.8ms
# image 49/88 /content/data/validation/images/8563bd21-IMG_8073_jpg.rf.7aaf6e87ccc2a4322fce10891b18ba5f.jpg: 640x640 1 damaged_warning_sign, 8.8ms
# image 50/88 /content/data/validation/images/862c6803-1-83-_jpg.rf.a7cfa1a196e695d64a332b0ea33e6e76.jpg: 640x640 1 mold_damp_wall, 8.8ms
# image 51/88 /content/data/validation/images/89ba1142-Merge_mp4-41_jpg.rf.fa901044abb7728cc651f712033582a6.jpg: 640x640 1 obstruction_walkway, 8.8ms
# image 52/88 /content/data/validation/images/9822631b-Merge_mp4-89_jpg.rf.5a704ab35bec94002ebbeafadfd6c78e.jpg: 640x640 1 obstruction_walkway, 11.2ms
# image 53/88 /content/data/validation/images/9d8c9ced-unfocused__closed_qt_mov-0000_jpg.rf.6e70bc8670efb027218889886d172ac1.jpg: 384x640 1 broken_door_lock, 7.9ms
# image 54/88 /content/data/validation/images/a5c54e27-Capture11_JPG_jpg.rf.307af19f02f2b5f8ec0f6ec847369cab.jpg: 640x640 1 damaged_warning_sign, 9.4ms
# image 55/88 /content/data/validation/images/a8b2c084-Capture82_jpg.rf.7abe63af48b975c56cf67a8bb765359e.jpg: 640x640 1 damaged_warning_sign, 8.8ms
# image 56/88 /content/data/validation/images/a8d5e5c0-IMG_8120_jpg.rf.da79cd8db7b28fb452f0e7a31be6c65b.jpg: 640x640 1 damaged_warning_sign, 8.8ms
# image 57/88 /content/data/validation/images/a9c6c9d0-1-21-_jpg.rf.958010c1dc97bcb1a29bee8e6a1b40e0.jpg: 640x640 1 mold_damp_wall, 8.0ms
# image 58/88 /content/data/validation/images/ad89663c-45495337-5d4c-41f5-a63e-1db7764cb9_N8CIINh.rf.de021c2ecb4ffa3777e242c280b29814.jpg: 640x640 1 damaged_warning_sign, 7.7ms
# image 59/88 /content/data/validation/images/ae132423-IMG_8102_jpg.rf.0ccf61dcb6da3d98bc7f1d72e71001b0.jpg: 640x640 1 damaged_warning_sign, 7.7ms
# image 60/88 /content/data/validation/images/afe9c5c7-night_qt_mov-0026_jpg.rf.a73ad5b2fee0821f576cedf0a9832673.jpg: 384x640 1 broken_door_lock, 15.7ms
# image 61/88 /content/data/validation/images/b4463a7a-open_2_qt_mov-0013_jpg.rf.6709f92db3d460841d3c9974cc7e2261.jpg: 384x640 1 broken_door_lock, 8.6ms
# image 62/88 /content/data/validation/images/b6d100aa-open_qt_mov-0011_jpg.rf.49765a809de6adc6d0bc2e30313190f6.jpg: 384x640 1 broken_door_lock, 7.8ms
# image 63/88 /content/data/validation/images/bb7ff91b-Merge_mp4-82_jpg.rf.b158944a6fb01117799400f060dbd528.jpg: 640x640 1 obstruction_walkway, 8.8ms
# image 64/88 /content/data/validation/images/bc6f2007-0aad64567664f31b63fe4a5041fd9b89-g_oH6092i.rf.981cc985b27c2b5f9845263d368929c8.jpg: 640x640 1 damaged_warning_sign, 8.3ms
# image 65/88 /content/data/validation/images/c0a807ce-Merge_mp4-21_jpg.rf.b65b458df0ffc5f0873b4f5237aaa3dc.jpg: 640x640 1 obstruction_walkway, 8.3ms
# image 66/88 /content/data/validation/images/c182276c-1-152-_jpg.rf.7a1069572c8baeb90b11f0028dcf8e70.jpg: 640x640 1 mold_damp_wall, 8.0ms
# image 67/88 /content/data/validation/images/c3306ccd-night_qt_mov-0001_jpg.rf.734ede185f7b8e1cf16afe2c5dd135ee.jpg: 384x640 1 broken_door_lock, 8.2ms
# image 68/88 /content/data/validation/images/c43c304f-Merge_mp4-35_jpg.rf.5feec908b3c6c63e4db6f653adfa7ac9.jpg: 640x640 1 obstruction_walkway, 8.3ms
# image 69/88 /content/data/validation/images/c50255ec-36_jpg.rf.11059be68d0d9544ebbee43b878bbf6f.jpg: 640x640 1 broken_door_lock, 7.6ms
# image 70/88 /content/data/validation/images/c6905383-Capture9_JPG_jpg.rf.ad706639952457165247452b0c382527.jpg: 640x640 1 damaged_warning_sign, 7.7ms
# image 71/88 /content/data/validation/images/c95d7a6d-32_jpg.rf.29a1bddd56ff146c746afe5957b6684a.jpg: 640x640 1 broken_door_lock, 7.6ms
# image 72/88 /content/data/validation/images/d046c8e2-Merge_mp4-22_jpg.rf.17a3b9e904059224a112e26030716014.jpg: 640x640 1 obstruction_walkway, 7.6ms
# image 73/88 /content/data/validation/images/d1216522-1-145-_jpg.rf.577d56dbb6107dceb0ba7f5dd0aff552.jpg: 640x640 1 mold_damp_wall, 8.5ms
# image 74/88 /content/data/validation/images/d482071f-image_197_jpeg.rf.0f0ca620a27b0f064f078719c191b891.jpg: 640x480 2 overflowing_trash_bins, 55.6ms
# image 75/88 /content/data/validation/images/d6a458b2-1-2-_jpg.rf.d8726d08d8d21ef5a0b3ba358803c3a1.jpg: 640x640 1 mold_damp_wall, 8.3ms
# image 76/88 /content/data/validation/images/d81c29d4-image3-22-_jpeg_jpg.rf.e7fd8565457c7c276b042f812c79e4c3.jpg: 640x640 1 damaged_warning_sign, 7.6ms
# image 77/88 /content/data/validation/images/dd1fa24d-image_148_jpeg.rf.c82368662d1fdb1b6d4e1f3f199f843f.jpg: 384x640 1 overflowing_trash_bin, 7.9ms
# image 78/88 /content/data/validation/images/df0c04b2-1_JMP_RGR_280621SIGN_02JPG_jpg.rf.93f55a8f3f9a20b38aa61e7b4c4ddb64.jpg: 640x640 1 damaged_warning_sign, 8.2ms
# image 79/88 /content/data/validation/images/df9f24a1-image7-9-_jpeg_jpg.rf.8e7e441625dbf66b86ce927750afe25c.jpg: 640x640 1 damaged_warning_sign, 7.6ms
# image 80/88 /content/data/validation/images/e51365af-image_49_jpeg.rf.3c38240c02898355273a5e0841c3ab99.jpg: 480x640 1 overflowing_trash_bin, 50.7ms
# image 81/88 /content/data/validation/images/e550c43b-Merge_mp4-80_jpg.rf.846a99a947a59c0c09924cd42e527051.jpg: 640x640 1 obstruction_walkway, 8.4ms
# image 82/88 /content/data/validation/images/e8136f13-1-91-_jpg.rf.6a748bad8d89845f926a3151f4f65ed3.jpg: 640x640 1 mold_damp_wall, 7.6ms
# image 83/88 /content/data/validation/images/ee8cf269-unfocused__closed_qt_mov-0008_jpg.rf.dd9c60767bfe276b1dff4c77659ab114.jpg: 384x640 1 broken_door_lock, 7.8ms
# image 84/88 /content/data/validation/images/eecfd7a5-IMG_8114_jpg.rf.18428335dd75b03ccd740c6f6f4cc351.jpg: 640x640 1 damaged_warning_sign, 8.6ms
# image 85/88 /content/data/validation/images/f09e2b44-IMG_8083_jpg.rf.388eac836d57631bba3a09dc4a7b0bc2.jpg: 640x640 1 damaged_warning_sign, 7.6ms
# image 86/88 /content/data/validation/images/f54426dc-1-32-_jpg.rf.989552bbcad52b83c5080e10df62b848.jpg: 640x640 1 mold_damp_wall, 7.6ms
# image 87/88 /content/data/validation/images/f9ee00b4-Merge_mp4-77_jpg.rf.2ce1906de6eccc2d939e47f0b3ceb90f.jpg: 640x640 1 obstruction_walkway, 7.6ms
# image 88/88 /content/data/validation/images/fa90d8f8-Merge_mp4-20_jpg.rf.f47533d868065b5ccc03637874811a5d.jpg: 640x640 1 obstruction_walkway, 7.6ms
# Speed: 1.8ms preprocess, 13.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /content/runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
import glob
from IPython.display import Image, display
for image_path in glob.glob(f'/content/runs/detect/predict/*.jpg')[:10]:
  display(Image(filename=image_path, height=400))
  print('\n')

# %% [markdown]
# The model should draw a box around each object of interest in each image. If it isn't doing a good job of detecting objects, here are a few tips:
#
# 1. Double-check your dataset to make sure there are no labeling errors or conflicting examples.
# 2. Increase the number of epochs used for training.
# 3. Use a larger model size (e.g. `yolo11l.pt`).
# 4. Add more images to the training dataset. See my [dataset video](https://www.youtube.com/watch?v=v0ssiOY6cfg) for tips on how to capture good training images and improve accuracy.
#
# You can also run the model on video files or other images images by uploading them to this notebook and using the above `!yolo detect predict` command, where `source` points to the location of the video file, image, or folder of images. The results will be saved in `runs/detect/predict`.
#
# Drawing boxes on images is great, but it isn't very useful in itself. It's also not very helpful to just run this models inside a Colab notebook: it's easier if we can just run it on a local computer. Continue to the next section to see how to download your newly trained model and run it on a local device.

# %% [markdown]
# #7.&nbsp;Deploy Model

# %% [markdown]
# Now that your custom model has been trained, it's ready to be downloaded and deployed in an application! YOLO models can run on a wide variety of hardware, including PCs, embedded systems, and phones. Ultralytics makes it easy to convert the YOLO models to various formats (`tflite`, `onnx`, etc.) and deploy them in a variety of environments.
#
# This section shows how to download the model and provides links to instructions for deploying it on your PC and edge devices like the Raspberry Pi.

# %% [markdown]
# ## 7.1 Download YOLO Model
#
# First, zip and download the trained model by running the code blocks below.
#
# The code creates a folder named `my_model`, moves the model weights into it, and renames them from `best.pt` to `my_model.pt`. It also adds the training results in case you want to reference them later. It then zips the folder as `my_model.zip`.

# %%
# Create "my_model" folder to store model weights and train results
# !mkdir /content/my_model
# !cp /content/runs/detect/train-5/weights/best.pt /content/my_model/my_model.pt
# !cp -r /content/runs/detect/train-5 /content/my_model

# Zip into "my_model.zip"
# %cd my_model
# !zip /content/my_model.zip my_model.pt
# !zip -r /content/my_model.zip train
# %cd /content
# Out:
# mkdir: cannot create directory ‘/content/my_model’: File exists
# /content/my_model
#   adding: my_model.pt (deflated 8%)
# updating: train/ (stored 0%)
# updating: train/args.yaml (deflated 53%)
# updating: train/weights/ (stored 0%)
# /content

# %%
# This takes forever for some reason, you can also just download the model from the sidebar
from google.colab import files

files.download('/content/my_model.zip')

# %% [markdown]
# ## 7.2 Deploy YOLO Model on Local Devices
#
# Next, we'll take our downloaded model and run it on a local device. This section provides instructions showing how to deploy YOLO models on various devices.
#
# I wrote a basic Python script, `yolo_detect.py`, that shows how to load a model, run inference on an image source, parse the inference results, and display boxes around each detected class in the image. The [script](https://github.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/blob/main/yolo_detect.py) gives an example of how to work with Ultralytics YOLO models in Python, and it can be used as a starting point for more advanced applications.

# %% [markdown]
# ### 7.2.1 Deploy on PC (Windows, Linux, or macOS)
#
# The easiest way to run Ultralytics models on a PC is using Anaconda. Anaconda sets up a virtual Python environment and allows you to easily install Ultralytics and PyTorch. It automatically installs CUDA and cuDNN, which allows you to speed up model inference with your NVIDIA GPU.
#
# > **NOTE:** My YouTube video (link to be added) shows how to deploy your model on a PC. It walks through the following steps, so watch the video if you prefer having visual instructions.
#
# **1. Download and Install Anaconda**
#
# Go to the Anaconda download page at https://anaconda.com/download, click the “skip registration” button, and then download the package for your OS. When it's finished downloading, run the installer and click through the installation steps. You can use the default options for installation.
#
# **2. Set up virtual environment**
#
# Once it's installed, run Anaconda Prompt from the Start Bar. (If you're on macOS or Linux, just open a command terminal).
#
# Issue the following commands to create a new Python environment and activate it:
#
# ```
# conda create --name yolo-env1 python=3.12 -y
# conda activate yolo-env1
# ```
#
# Install Ultralytics (which also installs import libraries like OpenCV-Python, Numpy, and PyTorch) by issuing the following command:
#
# ```
# pip install ultralytics
# ```
#
# If you have an NVIDIA GPU, you can install the GPU-enabled version of PyTorch by issuing the following command:
#
# ```
# pip install --upgrade torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu124
# ```
#
# **3. Extract downloaded model**
# Take the `my_model.zip` file you downloaded in Step 7.1 and unzip it to a folder on your PC. In the Anaconda Prompt terminal, move into the unzipped folder using:
#
# ```
# cd path/to/folder
# ```
#
# **4. Download and run yolo_detect.py**
#
# Download the `yolo_detect.py` script into the `my_model` folder using:
#
# ```
# curl -o yolo_detect.py https://raw.githubusercontent.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/refs/heads/main/yolo_detect.py
# ```
#
# Alright! We're ready to run the script. To run inference with a yolov8s model on a USB camera at 1280x720 resolution, issue:
#
# ```
# python yolo_detect.py --model my_model.pt --source usb0 --resolution 1280x720
# ```
#
# A window will appear showing a live feed from your webcam with boxes drawn around detected objects in each frame.
#
# You can also run the model on an video file, image, or folder of images. To see a full list of arguments for `yolo_detect.py`, issue `python yolo_detect.py --help` or see the [README file](https://github.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/blob/main/README.md).

# %% [markdown]
# ### 7.2.2 Deploy on Raspberry Pi
#
# Keep an eye out for an article showing how to convert YOLO models to NCNN format and run them on the Raspberry Pi!

# %% [markdown]
# # 8.&nbsp;Conclusion

# %% [markdown]
# Congratulations! You've successfully trained and deployed a YOLO object detection model. 😀
#
# Next, you can extend your application beyond just drawing boxes and counting objects. Add functionality like logging the number of objects detected over time or taking a picture when certain objects are detected. Check out some example applications at our GitHub repository: https://github.com/EdjeElectronics/Train-and-Deploy-YOLO-Models
#
# Thanks for working through this notebook, and good luck with your projects!

# %% [markdown]
# # Appendix: Common Errors

# %% [markdown]
# If you run into any errors working through this notebook, please do the following:
#
#
# - Double-check that the dataset files are set up in the correct folder structure
# - Make sure there are no typos or errors in your labelmap file
# - Google search the error to look for solutions
#
# If none of those help, please submit an [Issue](https://github.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/issues) on the GitHub page. In this section, I will add resolutions to common errors as they come up.
